# %%
'''trained_model = models.vgg16(pretrained=True)
trained_model

classifier_name, old_classifier = trained_model._modules.popitem()
print(classifier_name,'\n',old_classifier)
#add new hidden and dropout layers at the end
classifier_input_size = old_classifier[0].in_features
print(classifier_input_size)
classifier = nn.Sequential(OrderedDict([('drop1', nn.Dropout(p=0.45)),
                                           ('leakyrelu1', nn.LeakyReLU(0.8)),
                                           ('fc1', nn.Linear(classifier_input_size, 1))
                                           ]))

trained_model.add_module(classifier_name, classifier)

if train_on_gpu:
  print('moving')
  trained_model.cuda()

trained_model'''

# %%
# to read files from google drive, in case you're running on colab
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
data_dir = './drive/My Drive/gan_task/'
train_dir = data_dir
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch import optim
from torchvision import transforms, datasets, models
import numpy as np
from collections import OrderedDict
import os
import matplotlib.pyplot as plt
import pickle as pkl

# %matplotlib inline

train_on_gpu = torch.cuda.is_available()

# %%
print(len(os.listdir(data_dir+'1000px/')))
# Out:
# 193

# %%
# loading all images into training and validation dataset
batch_size = 12
data_transforms = transforms.Compose([transforms.Resize((512, 512)),
                                transforms.ToTensor()])

train_data = datasets.ImageFolder(train_dir, transform=data_transforms)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)

# %%
# helper scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    Y = feature_range[0]
    X = feature_range[1] - feature_range[0]
    x = x * X + Y
    
    return x

# %%
def gaussian_noise(ins, mean, stddev, is_training = True):
  if is_training:
    noise = torch.zeros(ins.shape, dtype=torch.float).cuda().detach()
    torch.nn.init.xavier_normal_(noise)
    #noise = Variable(ins.data.new(ins.size()).normal_(mean, stddev))
    return ins + noise
  return ins

# %%
# helper conv function
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    # append conv layer
    layers.append(conv_layer)
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):
    def __init__(self, conv_dim=32):
        super(Discriminator, self).__init__()
        self.conv_dim = conv_dim
        
        # complete init function
        self.conv1 = conv(3, self.conv_dim, 4, batch_norm = False)
        self.conv2 = conv(self.conv_dim, self.conv_dim * 2, 4)
        self.conv3 = conv(self.conv_dim * 2, self.conv_dim * 4, 4)
        self.conv4 = conv(self.conv_dim * 4, self.conv_dim * 8, 4)
        self.conv5 = conv(self.conv_dim * 8, self.conv_dim * 16, 4)
        self.conv5_1 = conv(self.conv_dim * 16, self.conv_dim * 16, 4, stride=1, padding=2)
        self.conv6 = conv(self.conv_dim * 16, self.conv_dim * 32, 4)
        
        self.fc = nn.Linear(self.conv_dim * 32 * 8 * 8, 1)

    def forward(self, x):
        # complete forward function
        x = gaussian_noise(x, 0, 0.0001)
        x = F.leaky_relu(self.conv1(x))
        #print('x shape =', x.shape)
        x = F.leaky_relu(self.conv2(x))
        x = F.leaky_relu(self.conv3(x))
        #x = gaussian_noise(x, 0, 0.0001)
        x = F.leaky_relu(self.conv4(x), 0.3)
        #x = gaussian_noise(x, 0, 0.0001)
        x = F.leaky_relu(self.conv5(x), 0.4)
        #print('shape before =', x.shape)
        x = F.leaky_relu(self.conv5_1(x))
        #print('shape after =', x.shape)
        x = F.leaky_relu(self.conv6(x), 0.4)
        #print('x shape right before fc =', x.shape)
        x = x.view(-1, self.conv_dim * 32 * 8 * 8)
        x = self.fc(x)
        
        #x = trained_model(x)
        
        return x

# %%
# helper deconv function
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    layers = []
    deconv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias = False)
    layers.append(deconv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        super(Generator, self).__init__()
        self.conv_dim = conv_dim
        self.drop = nn.Dropout(0.5)
        self.fc = nn.Linear(z_size, conv_dim * 16 * 16 * 16)
        
        self.pixel_shuffle = nn.PixelShuffle(2)
        
        #self.de_conv1 = deconv(conv_dim * 16, conv_dim * 8, 4)
        #self.de_conv2 = deconv(conv_dim * 8, conv_dim * 4, 4)
        self.de_conv3 = deconv(conv_dim * 4, conv_dim * 4, 4)
        self.de_conv4 = deconv(conv_dim * 4, conv_dim * 2, 4)
        
        
        self.de_conv5 = deconv(conv_dim * 2, conv_dim, 4)
        self.de_conv6 = deconv(conv_dim, 3, 2, padding=0, batch_norm = False)

    def forward(self, x):
        # complete forward function
        x = F.leaky_relu(self.fc(x))
        x = self.drop(x)
        x = x.view(-1, self.conv_dim*16, 16, 16)
        
        x = F.relu(self.pixel_shuffle(x))
        #x = F.leaky_relu(self.de_conv1(x), 0.2)
        #x = F.leaky_relu(self.de_conv2(x), 0.2)
        x = F.relu(self.de_conv3(x))
        x = F.relu(self.de_conv4(x))
        x = self.drop(x)
        x = F.leaky_relu(self.de_conv5(x), 0.3)
        x = torch.tanh(self.de_conv6(x))
        
        return x

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__    
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        nn.init.xavier_normal_(m.weight.data)

# %%
# define hyperparams
conv_dim = 128
z_size = 128

# define discriminator and generator
D = Discriminator(conv_dim)
G = Generator(z_size=z_size, conv_dim=conv_dim)

D.apply(weights_init_normal)
G.apply(weights_init_normal)
'''print(D)
print()
print(G)'''
# Out:
# 'print(D)\nprint()\nprint(G)'

# %%
def real_loss(D_out, flip=False):
    batch_size = D_out.size(0)
    #labels = torch.ones(batch_size) # real labels = 1
    labels = torch.rand(batch_size).uniform_(0.7, 1.2) # real labels = random numbers between 0.7 and 1.2
    if flip:
      labels = torch.rand(batch_size).uniform_(0, 0.3) # real labels = random numbers between 0 and 0.3
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    #print(D_out.shape, labels.shape)
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
    #labels = torch.zeros(batch_size) # fake labels = 0
    labels = torch.rand(batch_size).uniform_(0, 0.3) # fake labels = random numbers between 0 and 0.3
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %%
# params
lr_d = 0.0005
lr_g = 0.0005
beta1= 0.5
beta2= 0.999

# Create optimizers for the discriminator and generator
# use momentum here?
d_optimizer = optim.SGD(D.parameters(), lr_d, momentum = 0.6)
g_optimizer = optim.Adam(G.parameters(), lr_g, [beta1, beta2])

# %%
if train_on_gpu:
    # move models to GPU
    G.cuda()
    D.cuda()
    print('GPU available for training. Models moved to GPU')
# Out:
# GPU available for training. Models moved to GPU

# %%
import pickle as pkl
import random

# training hyperparams
num_epochs = 250

# keep track of loss and generated, "fake" samples
samples = []
losses = []

# Get some fixed data for sampling. These are images that are held
# constant throughout training, and allow us to inspect the model's performance
sample_size = 2
fixed_z = torch.zeros((sample_size, z_size), dtype=torch.float).cuda()
torch.nn.init.xavier_normal_(fixed_z)
if train_on_gpu:
    fixed_z = fixed_z.cuda()

# train the network
for epoch in range(num_epochs):
    d_loss_net = g_loss_net = 0
    batch_count = 0
    for real_images, _ in train_loader:
        if real_images.shape[0] < batch_size:
            continue
      
        batch_count += 1
        batch_size = real_images.size(0)
        real_images = scale(real_images)
        # ============================================
        #            TRAIN THE DISCRIMINATOR
        # ============================================

        d_optimizer.zero_grad()

        # 1. Train with real images

        # Compute the discriminator losses on real images 
        if train_on_gpu:
            real_images = real_images.cuda()

        D_real = D(real_images)
        d_real_loss = real_loss(D_real)

        # 2. Train with fake images

        # Generate fake images
        z = torch.zeros((batch_size, z_size), dtype=torch.float).cuda()
        torch.nn.init.xavier_normal_(z)
        # move x to GPU, if available
        if train_on_gpu:
            z = z.cuda()
        fake_images = G(z)

        # Compute the discriminator losses on fake images 
        #print('fake image shape =', fake_images.shape)
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)

        # add up loss and perform backprop
        d_loss = d_real_loss + d_fake_loss
        d_loss_net += d_loss.item() / batch_size
        d_loss.backward()
        d_optimizer.step()


        # =========================================
        #            TRAIN THE GENERATOR
        # =========================================
        g_optimizer.zero_grad()

        # 1. Train with fake images and flipped labels

        # Generate fake images
        z = torch.zeros((batch_size, z_size), dtype=torch.float).cuda()
        torch.nn.init.xavier_normal_(z)
        if train_on_gpu:
            z = z.cuda()
        fake_images = G(z)

        # Compute the discriminator losses on fake images 
        # using flipped labels!
        # set D to eval?
        D_fake = D(fake_images)
        
        #flip = random.randint(0, 3) == 2
        g_criterion_new = nn.MSELoss()
        g_loss = real_loss(D_fake) + g_criterion_new(fake_images, real_images) # use real loss
        g_loss_net += g_loss.item() / batch_size
        # perform backprop
        g_loss.backward()
        g_optimizer.step()
           
    if epoch%50 == 0:
      # generate and save sample, fake images
      G.eval() # for generating samples
      samples_z = G(fixed_z)
      samples.append(samples_z.detach())
    G.train() # back to training mode
    
    # Print some loss stats
    # append discriminator loss and generator loss
    #losses.append((sum(d_loss_all)/len(d_loss_all), sum(g_loss_all)/len(g_loss_all)))
    # print discriminator and generator loss
    print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
            epoch+1, num_epochs, d_loss_net / batch_count, g_loss_net / batch_count))
    #torch.cuda.empty_cache()
# Out:
# Epoch [    1/  250] | d_loss: 0.2739 | g_loss: 0.1006
# Epoch [    2/  250] | d_loss: 0.3119 | g_loss: 0.2281
# Epoch [    3/  250] | d_loss: 0.1579 | g_loss: 0.3820
# Epoch [    4/  250] | d_loss: 0.1850 | g_loss: 0.5565
# Epoch [    5/  250] | d_loss: 0.1771 | g_loss: 0.8341
# Epoch [    6/  250] | d_loss: 0.3008 | g_loss: 1.2194
# Epoch [    7/  250] | d_loss: 0.3087 | g_loss: 0.9990
# Epoch [    8/  250] | d_loss: 0.3776 | g_loss: 1.0874
# Epoch [    9/  250] | d_loss: 0.3976 | g_loss: 1.0501
# Epoch [   10/  250] | d_loss: 0.2946 | g_loss: 0.9410
# Epoch [   11/  250] | d_loss: 0.2955 | g_loss: 0.9053
# Epoch [   12/  250] | d_loss: 0.2610 | g_loss: 0.7227
# Epoch [   13/  250] | d_loss: 0.1464 | g_loss: 0.4298
# Epoch [   14/  250] | d_loss: 0.2522 | g_loss: 0.8053
# Epoch [   15/  250] | d_loss: 0.2515 | g_loss: 0.6439
# Epoch [   16/  250] | d_loss: 0.2042 | g_loss: 0.5887
# Epoch [   17/  250] | d_loss: 0.2583 | g_loss: 0.6567
# Epoch [   18/  250] | d_loss: 0.1668 | g_loss: 0.4967
# Epoch [   19/  250] | d_loss: 0.1829 | g_loss: 0.5004
# Epoch [   20/  250] | d_loss: 0.1546 | g_loss: 0.4611
# Epoch [   21/  250] | d_loss: 0.1860 | g_loss: 0.5256
# Epoch [   22/  250] | d_loss: 0.1290 | g_loss: 0.4078
# Epoch [   23/  250] | d_loss: 0.1428 | g_loss: 0.3715
# Epoch [   24/  250] | d_loss: 0.1114 | g_loss: 0.3654
# Epoch [   25/  250] | d_loss: 0.1646 | g_loss: 0.2977
# Epoch [   26/  250] | d_loss: 0.1433 | g_loss: 0.2550
# Epoch [   27/  250] | d_loss: 0.1160 | g_loss: 0.3473
# Epoch [   28/  250] | d_loss: 0.0984 | g_loss: 0.2748
# Epoch [   29/  250] | d_loss: 0.1078 | g_loss: 0.2614
# Epoch [   30/  250] | d_loss: 0.1082 | g_loss: 0.2856
# Epoch [   31/  250] | d_loss: 0.1148 | g_loss: 0.2672
# Epoch [   32/  250] | d_loss: 0.1675 | g_loss: 0.2863
# Epoch [   33/  250] | d_loss: 0.1426 | g_loss: 0.2443
# Epoch [   34/  250] | d_loss: 0.1335 | g_loss: 0.2433
# Epoch [   35/  250] | d_loss: 0.1285 | g_loss: 0.2292
# Epoch [   36/  250] | d_loss: 0.1285 | g_loss: 0.2640
# Epoch [   37/  250] | d_loss: 0.1060 | g_loss: 0.2458
# Epoch [   38/  250] | d_loss: 0.1149 | g_loss: 0.2510
# Epoch [   39/  250] | d_loss: 0.1255 | g_loss: 0.3002
# Epoch [   40/  250] | d_loss: 0.1385 | g_loss: 0.2212
# Epoch [   41/  250] | d_loss: 0.1105 | g_loss: 0.2402
# Epoch [   42/  250] | d_loss: 0.1080 | g_loss: 0.2081
# Epoch [   43/  250] | d_loss: 0.0971 | g_loss: 0.1960
# Epoch [   44/  250] | d_loss: 0.1228 | g_loss: 0.1917
# Epoch [   45/  250] | d_loss: 0.1202 | g_loss: 0.2147
# Epoch [   46/  250] | d_loss: 0.1175 | g_loss: 0.2402
# Epoch [   47/  250] | d_loss: 0.0992 | g_loss: 0.2450
# Epoch [   48/  250] | d_loss: 0.1052 | g_loss: 0.2013
# Epoch [   49/  250] | d_loss: 0.1014 | g_loss: 0.3015
# Epoch [   50/  250] | d_loss: 0.1269 | g_loss: 0.2452
# Epoch [   51/  250] | d_loss: 0.1107 | g_loss: 0.2277
# Epoch [   52/  250] | d_loss: 0.1758 | g_loss: 0.3143
# Epoch [   53/  250] | d_loss: 0.1345 | g_loss: 0.3530
# Epoch [   54/  250] | d_loss: 0.0901 | g_loss: 0.3065
# Epoch [   55/  250] | d_loss: 0.0990 | g_loss: 0.2913
# Epoch [   56/  250] | d_loss: 0.0930 | g_loss: 0.2299
# Epoch [   57/  250] | d_loss: 0.0984 | g_loss: 0.3151
# Epoch [   58/  250] | d_loss: 0.0942 | g_loss: 0.2824
# Epoch [   59/  250] | d_loss: 0.0998 | g_loss: 0.2850
# Epoch [   60/  250] | d_loss: 0.1305 | g_loss: 0.4973
# Epoch [   61/  250] | d_loss: 0.0943 | g_loss: 0.2682
# Epoch [   62/  250] | d_loss: 0.0889 | g_loss: 0.3445
# Epoch [   63/  250] | d_loss: 0.0886 | g_loss: 0.3106
# Epoch [   64/  250] | d_loss: 0.0946 | g_loss: 0.3107
# Epoch [   65/  250] | d_loss: 0.0934 | g_loss: 0.4253
# Epoch [   66/  250] | d_loss: 0.1024 | g_loss: 0.4203
# Epoch [   67/  250] | d_loss: 0.0954 | g_loss: 0.2876
# Epoch [   68/  250] | d_loss: 0.0837 | g_loss: 0.2592
# Epoch [   69/  250] | d_loss: 0.1277 | g_loss: 0.4913
# Epoch [   70/  250] | d_loss: 0.0793 | g_loss: 0.2777
# Epoch [   71/  250] | d_loss: 0.0628 | g_loss: 0.2244
# Epoch [   72/  250] | d_loss: 0.0749 | g_loss: 0.2337
# Epoch [   73/  250] | d_loss: 0.0703 | g_loss: 0.2533
# Epoch [   74/  250] | d_loss: 0.0935 | g_loss: 0.2784
# Epoch [   75/  250] | d_loss: 0.0981 | g_loss: 0.3117
# Epoch [   76/  250] | d_loss: 0.0764 | g_loss: 0.2889
# Epoch [   77/  250] | d_loss: 0.0750 | g_loss: 0.2481
# Epoch [   78/  250] | d_loss: 0.1053 | g_loss: 0.3298
# Epoch [   79/  250] | d_loss: 0.0759 | g_loss: 0.2499
# Epoch [   80/  250] | d_loss: 0.0757 | g_loss: 0.2367
# Epoch [   81/  250] | d_loss: 0.0750 | g_loss: 0.2259
# Epoch [   82/  250] | d_loss: 0.0751 | g_loss: 0.2374
# Epoch [   83/  250] | d_loss: 0.0787 | g_loss: 0.3113
# Epoch [   84/  250] | d_loss: 0.0853 | g_loss: 0.2906
# Epoch [   85/  250] | d_loss: 0.0744 | g_loss: 0.2225
# Epoch [   86/  250] | d_loss: 0.0708 | g_loss: 0.2230
# Epoch [   87/  250] | d_loss: 0.0862 | g_loss: 0.2688
# Epoch [   88/  250] | d_loss: 0.1046 | g_loss: 0.4104
# Epoch [   89/  250] | d_loss: 0.0725 | g_loss: 0.2271
# Epoch [   90/  250] | d_loss: 0.0719 | g_loss: 0.2384
# Epoch [   91/  250] | d_loss: 0.0679 | g_loss: 0.2162
# Epoch [   92/  250] | d_loss: 0.0607 | g_loss: 0.2163
# Epoch [   93/  250] | d_loss: 0.0723 | g_loss: 0.2511
# Epoch [   94/  250] | d_loss: 0.0735 | g_loss: 0.3008
# Epoch [   95/  250] | d_loss: 0.0696 | g_loss: 0.2381
# Epoch [   96/  250] | d_loss: 0.0515 | g_loss: 0.1987
# Epoch [   97/  250] | d_loss: 0.0655 | g_loss: 0.2377
# Epoch [   98/  250] | d_loss: 0.0653 | g_loss: 0.1837
# Epoch [   99/  250] | d_loss: 0.0650 | g_loss: 0.2355
# Epoch [  100/  250] | d_loss: 0.0832 | g_loss: 0.3125
# Epoch [  101/  250] | d_loss: 0.0748 | g_loss: 0.2020
# Epoch [  102/  250] | d_loss: 0.0603 | g_loss: 0.2110
# Epoch [  103/  250] | d_loss: 0.0611 | g_loss: 0.2073
# Epoch [  104/  250] | d_loss: 0.0631 | g_loss: 0.1972
# Epoch [  105/  250] | d_loss: 0.0598 | g_loss: 0.2107
# Epoch [  106/  250] | d_loss: 0.0647 | g_loss: 0.2157
# Epoch [  107/  250] | d_loss: 0.0734 | g_loss: 0.2033
# Epoch [  108/  250] | d_loss: 0.0618 | g_loss: 0.1966
# Epoch [  109/  250] | d_loss: 0.0725 | g_loss: 0.2449
# Epoch [  110/  250] | d_loss: 0.0866 | g_loss: 0.3169
# Epoch [  111/  250] | d_loss: 0.1149 | g_loss: 0.5537
# Epoch [  112/  250] | d_loss: 0.1530 | g_loss: 0.3157
# Epoch [  113/  250] | d_loss: 0.1121 | g_loss: 0.1578
# Epoch [  114/  250] | d_loss: 0.1457 | g_loss: 0.1611
# Epoch [  115/  250] | d_loss: 0.1450 | g_loss: 0.1589
# Epoch [  116/  250] | d_loss: 0.1491 | g_loss: 0.1249
# Epoch [  117/  250] | d_loss: 0.1225 | g_loss: 0.1837
# Epoch [  118/  250] | d_loss: 0.0963 | g_loss: 0.1680
# Epoch [  119/  250] | d_loss: 0.0957 | g_loss: 0.1882
# Epoch [  120/  250] | d_loss: 0.0949 | g_loss: 0.1758
# Epoch [  121/  250] | d_loss: 0.0956 | g_loss: 0.1984
# Epoch [  122/  250] | d_loss: 0.1214 | g_loss: 0.2049
# Epoch [  123/  250] | d_loss: 0.0817 | g_loss: 0.2133
# Epoch [  124/  250] | d_loss: 0.1373 | g_loss: 0.2555
# Epoch [  125/  250] | d_loss: 0.0930 | g_loss: 0.2135
# Epoch [  126/  250] | d_loss: 0.0962 | g_loss: 0.2125
# Epoch [  127/  250] | d_loss: 0.1080 | g_loss: 0.2520
# Epoch [  128/  250] | d_loss: 0.1041 | g_loss: 0.1970
# Epoch [  129/  250] | d_loss: 0.0947 | g_loss: 0.2010
# Epoch [  130/  250] | d_loss: 0.0852 | g_loss: 0.2056
# Epoch [  131/  250] | d_loss: 0.0900 | g_loss: 0.2357
# Epoch [  132/  250] | d_loss: 0.1017 | g_loss: 0.2653
# Epoch [  133/  250] | d_loss: 0.1095 | g_loss: 0.2348
# Epoch [  134/  250] | d_loss: 0.1089 | g_loss: 0.2342
# Epoch [  135/  250] | d_loss: 0.1254 | g_loss: 0.2936
# Epoch [  136/  250] | d_loss: 0.2056 | g_loss: 0.4983
# Epoch [  137/  250] | d_loss: 0.1717 | g_loss: 0.3792
# Epoch [  138/  250] | d_loss: 0.1073 | g_loss: 0.2510
# Epoch [  139/  250] | d_loss: 0.1104 | g_loss: 0.2452
# Epoch [  140/  250] | d_loss: 0.0875 | g_loss: 0.2381
# Epoch [  141/  250] | d_loss: 0.0774 | g_loss: 0.2208
# Epoch [  142/  250] | d_loss: 0.1048 | g_loss: 0.2665
# Epoch [  143/  250] | d_loss: 0.1368 | g_loss: 0.3386
# Epoch [  144/  250] | d_loss: 0.1153 | g_loss: 0.3077
# Epoch [  145/  250] | d_loss: 0.1292 | g_loss: 0.1974
# Epoch [  146/  250] | d_loss: 0.1178 | g_loss: 0.2433
# Epoch [  147/  250] | d_loss: 0.0870 | g_loss: 0.2106
# Epoch [  148/  250] | d_loss: 0.0942 | g_loss: 0.1962
# Epoch [  149/  250] | d_loss: 0.0916 | g_loss: 0.2107
# Epoch [  150/  250] | d_loss: 0.1095 | g_loss: 0.1856
# Epoch [  151/  250] | d_loss: 0.0792 | g_loss: 0.2276
# Epoch [  152/  250] | d_loss: 0.0927 | g_loss: 0.2378
# Epoch [  153/  250] | d_loss: 0.1005 | g_loss: 0.2362
# Epoch [  154/  250] | d_loss: 0.0903 | g_loss: 0.2105
# Epoch [  155/  250] | d_loss: 0.1001 | g_loss: 0.1894
# Epoch [  156/  250] | d_loss: 0.0946 | g_loss: 0.2260
# Epoch [  157/  250] | d_loss: 0.0974 | g_loss: 0.2798
# Epoch [  158/  250] | d_loss: 0.1007 | g_loss: 0.2317
# Epoch [  159/  250] | d_loss: 0.0770 | g_loss: 0.2070
# Epoch [  160/  250] | d_loss: 0.0863 | g_loss: 0.1946
# Epoch [  161/  250] | d_loss: 0.0966 | g_loss: 0.2548
# Epoch [  162/  250] | d_loss: 0.1130 | g_loss: 0.2867
# Epoch [  163/  250] | d_loss: 0.1200 | g_loss: 0.2543
# Epoch [  164/  250] | d_loss: 0.1062 | g_loss: 0.2576
# Epoch [  165/  250] | d_loss: 0.0927 | g_loss: 0.2731
# Epoch [  166/  250] | d_loss: 0.1136 | g_loss: 0.2649
# Epoch [  167/  250] | d_loss: 0.0810 | g_loss: 0.2244
# Epoch [  168/  250] | d_loss: 0.0948 | g_loss: 0.2250
# Epoch [  169/  250] | d_loss: 0.0867 | g_loss: 0.2056
# Epoch [  170/  250] | d_loss: 0.0901 | g_loss: 0.2376
# Epoch [  171/  250] | d_loss: 0.0751 | g_loss: 0.1764
# Epoch [  172/  250] | d_loss: 0.0922 | g_loss: 0.2539
# Epoch [  173/  250] | d_loss: 0.1059 | g_loss: 0.2379
# Epoch [  174/  250] | d_loss: 0.0943 | g_loss: 0.2130
# Epoch [  175/  250] | d_loss: 0.1074 | g_loss: 0.2184
# Epoch [  176/  250] | d_loss: 0.0917 | g_loss: 0.2205
# Epoch [  177/  250] | d_loss: 0.0858 | g_loss: 0.2227
# Epoch [  178/  250] | d_loss: 0.0788 | g_loss: 0.2122
# Epoch [  179/  250] | d_loss: 0.0779 | g_loss: 0.2073
# Epoch [  180/  250] | d_loss: 0.0937 | g_loss: 0.2206
# Epoch [  181/  250] | d_loss: 0.1126 | g_loss: 0.2688
# Epoch [  182/  250] | d_loss: 0.1045 | g_loss: 0.3067
# Epoch [  183/  250] | d_loss: 0.0839 | g_loss: 0.2698
# Epoch [  184/  250] | d_loss: 0.0805 | g_loss: 0.2253
# Epoch [  185/  250] | d_loss: 0.0838 | g_loss: 0.1945
# Epoch [  186/  250] | d_loss: 0.0776 | g_loss: 0.1956
# Epoch [  187/  250] | d_loss: 0.0844 | g_loss: 0.2206
# Epoch [  188/  250] | d_loss: 0.0973 | g_loss: 0.2490
# Epoch [  189/  250] | d_loss: 0.0873 | g_loss: 0.2904
# Epoch [  190/  250] | d_loss: 0.0779 | g_loss: 0.2246
# Epoch [  191/  250] | d_loss: 0.0817 | g_loss: 0.2163
# Epoch [  192/  250] | d_loss: 0.0942 | g_loss: 0.2280
# Epoch [  193/  250] | d_loss: 0.0812 | g_loss: 0.2086
# Epoch [  194/  250] | d_loss: 0.0770 | g_loss: 0.2081
# Epoch [  195/  250] | d_loss: 0.0841 | g_loss: 0.2286
# Epoch [  196/  250] | d_loss: 0.0777 | g_loss: 0.1992
# Epoch [  197/  250] | d_loss: 0.0875 | g_loss: 0.2093
# Epoch [  198/  250] | d_loss: 0.0715 | g_loss: 0.2070
# Epoch [  199/  250] | d_loss: 0.0897 | g_loss: 0.2882
# Epoch [  200/  250] | d_loss: 0.0825 | g_loss: 0.3373
# Epoch [  201/  250] | d_loss: 0.0822 | g_loss: 0.3030
# Epoch [  202/  250] | d_loss: 0.0839 | g_loss: 0.2228
# Epoch [  203/  250] | d_loss: 0.0806 | g_loss: 0.2199
# Epoch [  204/  250] | d_loss: 0.0719 | g_loss: 0.1992
# Epoch [  205/  250] | d_loss: 0.0775 | g_loss: 0.2452
# Epoch [  206/  250] | d_loss: 0.0881 | g_loss: 0.2381
# Epoch [  207/  250] | d_loss: 0.0955 | g_loss: 0.2904
# Epoch [  208/  250] | d_loss: 0.0898 | g_loss: 0.2610
# Epoch [  209/  250] | d_loss: 0.0847 | g_loss: 0.2609
# Epoch [  210/  250] | d_loss: 0.0901 | g_loss: 0.2190
# Epoch [  211/  250] | d_loss: 0.0901 | g_loss: 0.2338
# Epoch [  212/  250] | d_loss: 0.0840 | g_loss: 0.2579
# Epoch [  213/  250] | d_loss: 0.0686 | g_loss: 0.2189
# Epoch [  214/  250] | d_loss: 0.0789 | g_loss: 0.2038
# Epoch [  215/  250] | d_loss: 0.0832 | g_loss: 0.2392
# Epoch [  216/  250] | d_loss: 0.0846 | g_loss: 0.2333
# Epoch [  217/  250] | d_loss: 0.0661 | g_loss: 0.2024
# Epoch [  218/  250] | d_loss: 0.0915 | g_loss: 0.2710
# Epoch [  219/  250] | d_loss: 0.0815 | g_loss: 0.2290
# Epoch [  220/  250] | d_loss: 0.0883 | g_loss: 0.2164
# Epoch [  221/  250] | d_loss: 0.0751 | g_loss: 0.1953
# Epoch [  222/  250] | d_loss: 0.0751 | g_loss: 0.2068
# Epoch [  223/  250] | d_loss: 0.0772 | g_loss: 0.2222
# Epoch [  224/  250] | d_loss: 0.0872 | g_loss: 0.2280
# Epoch [  225/  250] | d_loss: 0.0960 | g_loss: 0.2201
# Epoch [  226/  250] | d_loss: 0.0911 | g_loss: 0.2169
# Epoch [  227/  250] | d_loss: 0.0867 | g_loss: 0.2385
# Epoch [  228/  250] | d_loss: 0.0774 | g_loss: 0.2160
# Epoch [  229/  250] | d_loss: 0.0867 | g_loss: 0.2209
# Epoch [  230/  250] | d_loss: 0.0816 | g_loss: 0.2079
# Epoch [  231/  250] | d_loss: 0.0752 | g_loss: 0.1940
# Epoch [  232/  250] | d_loss: 0.0839 | g_loss: 0.1949
# Epoch [  233/  250] | d_loss: 0.0798 | g_loss: 0.2076
# Epoch [  234/  250] | d_loss: 0.0819 | g_loss: 0.2067
# Epoch [  235/  250] | d_loss: 0.0898 | g_loss: 0.1986
# Epoch [  236/  250] | d_loss: 0.0723 | g_loss: 0.2032
# Epoch [  237/  250] | d_loss: 0.0771 | g_loss: 0.2214
# Epoch [  238/  250] | d_loss: 0.0782 | g_loss: 0.2325
# Epoch [  239/  250] | d_loss: 0.0738 | g_loss: 0.2304
# Epoch [  240/  250] | d_loss: 0.0894 | g_loss: 0.2605
# Epoch [  241/  250] | d_loss: 0.0785 | g_loss: 0.2588
# Epoch [  242/  250] | d_loss: 0.0730 | g_loss: 0.2357
# Epoch [  243/  250] | d_loss: 0.0961 | g_loss: 0.2674
# Epoch [  244/  250] | d_loss: 0.0700 | g_loss: 0.2422
# Epoch [  245/  250] | d_loss: 0.0680 | g_loss: 0.2148
# Epoch [  246/  250] | d_loss: 0.0812 | g_loss: 0.2693
# Epoch [  247/  250] | d_loss: 0.0949 | g_loss: 0.2726
# Epoch [  248/  250] | d_loss: 0.0777 | g_loss: 0.2613
# Epoch [  249/  250] | d_loss: 0.0911 | g_loss: 0.3141
# Epoch [  250/  250] | d_loss: 0.0788 | g_loss: 0.2480

# %%
# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(20,20), nrows=2, ncols=1, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((512,512,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)
_ = view_samples(-1, samples)

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()
